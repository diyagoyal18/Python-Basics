# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np

# %%
x=np.arange(0,10)
y=np.arange(11,21)

# %%
#plt scatter
plt.scatter(x,y,c='r')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Graph in 2D')
plt.savefig('graph.png')

# %%
y=x*x
plt.plot(x,y,'r*',linestyle='dashed',linewidth=2,markersize=12)

# %%
np.pi
# Out:
# 3.141592653589793

# %%
x= np.arange(0,4*np.pi,0.1)
y=np.sin(x)
plt.title('sine wave form')
plt.plot(x,y)
plt.show()

# %%
##bar plot
x=[2,8,10]
y=[11,16,9]
x2=[3,9,11]
y2=[6,15,7]
plt.bar(x,y,align='center')
plt.bar(x2,y2,color='g')
# Out:
# <BarContainer object of 3 artists>

# %%
##histogram
a=np.array([22,32,4,34.54,87,5,32,45,22,11,39])
plt.hist(a)
# Out:
# (array([3., 0., 2., 3., 2., 0., 0., 0., 0., 1.]),
#  array([ 4. , 12.3, 20.6, 28.9, 37.2, 45.5, 53.8, 62.1, 70.4, 78.7, 87. ]),
#  <BarContainer object of 10 artists>)

# %%
## boxplot
data= [np.random.normal(0, std,100) for std in range(1,4)]
plt.boxplot(data,vert=True,patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x182a1c2f550>,
#   <matplotlib.lines.Line2D at 0x182a1c64b10>,
#   <matplotlib.lines.Line2D at 0x182a1c70750>,
#   <matplotlib.lines.Line2D at 0x182a1c712d0>,
#   <matplotlib.lines.Line2D at 0x182a1c80e90>,
#   <matplotlib.lines.Line2D at 0x182a1c81ad0>],
#  'caps': [<matplotlib.lines.Line2D at 0x182a1c65650>,
#   <matplotlib.lines.Line2D at 0x182a1c65ed0>,
#   <matplotlib.lines.Line2D at 0x182a1c71d10>,
#   <matplotlib.lines.Line2D at 0x182a1c72790>,
#   <matplotlib.lines.Line2D at 0x182a1c82510>,
#   <matplotlib.lines.Line2D at 0x182a1c82f90>],
#  'boxes': [<matplotlib.patches.PathPatch at 0x182a1c26990>,
#   <matplotlib.patches.PathPatch at 0x182a1c65b10>,
#   <matplotlib.patches.PathPatch at 0x182a1c80590>],
#  'medians': [<matplotlib.lines.Line2D at 0x182a1c66990>,
#   <matplotlib.lines.Line2D at 0x182a1c73110>,
#   <matplotlib.lines.Line2D at 0x182a1c83890>],
#  'fliers': [<matplotlib.lines.Line2D at 0x182a1c67410>,
#   <matplotlib.lines.Line2D at 0x182a1c73b90>,
#   <matplotlib.lines.Line2D at 0x182a1c88410>],
#  'means': []}

# %%
#pie chart
labels='python','c++', 'java', 'ruby'
sizes=[215,130,245,210]
colors=['green','yellow','blue','orange']
explode=(0.1,0.3,0,0.3)

plt.pie(sizes,explode=explode,labels=labels,colors=colors,autopct='%1.1f%%', shadow=True)
plt.axis('equal')
plt.show()
